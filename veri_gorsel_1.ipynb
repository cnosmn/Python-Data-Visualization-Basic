# %%
import seaborn as sb
import pandas as pd
import numpy as np

data=sb.load_dataset("flights")
data.head(15)
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141

# %%
data.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
data.isnull().values.any()
#eksik veri kontroll
# Out:
# False

# %%
data.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
data["year"].value_counts()
# Out:
# 1949    12
# 1950    12
# 1951    12
# 1952    12
# 1953    12
# 1954    12
# 1955    12
# 1956    12
# 1957    12
# 1958    12
# 1959    12
# 1960    12
# Name: year, dtype: int64

# %%
kat_df=data.select_dtypes(include=["category"])
kat_df
# Out:
#     month
# 0     Jan
# 1     Feb
# 2     Mar
# 3     Apr
# 4     May
# ..    ...
# 139   Aug
# 140   Sep
# 141   Oct
# 142   Nov
# 143   Dec
#
# [144 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
data["month"].value_counts().plot.barh().set_title("yolcular");

# %%
data.pivot_table("passengers",index="month",columns="year")
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
(sb.barplot(x="month",
            y=data.month.index,
            data=data));

# %%
(sb.catplot(x="month",y="passengers",data=data))

# %%
(sb.catplot(x="month",y="passengers",hue="year",data=data))

# %%
titan=sb.load_dataset("titanic")
titan.head(15)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
sb.catplot(x="age",y="sex",hue="survived",data=titan);

# %%
sb.barplot(x="age",y="sex",hue="survived",data=titan)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sb.displot(data=titan,x="age",y="sex",hue="survived",bins=50)

# %%
sb.displot(data=titan,x="age",bins=10,kde=False)

# %%
sb.displot(data=titan,x="age",bins=10,kde=True)

# %%
sb.displot(titan.age,rug=False,kind='hist')

# %%
>>> import seaborn as sns; sns.set(style="ticks", color_codes=True)
>>> iris = sns.load_dataset("iris")
>>> g = sns.pairplot(iris)

# %%
sb.boxplot(titan.survived,titan.age)
# Out:
# C:\Users\osman\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sb.violinplot(titan.survived,titan.age)
# Out:
# C:\Users\osman\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='age'>
